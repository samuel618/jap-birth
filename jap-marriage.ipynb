# %%
import pandas as pd
import numpy as np

# %% [markdown]
# # Data Selection

# %%
# Load dataset
df = pd.read_csv("japan_international_marriage.csv")

# Preview the dataset
df.head()
# Out:
#    year  both_japanese  husb_jpn_wife_american  husb_jpn_wife_brazilian  \
# 0  1965         950696                      64                      NaN
# 1  1970        1023859                      75                      NaN
# 2  1971        1085639                      97                      NaN
# 3  1972        1093988                     102                      NaN
# 4  1973        1065730                     122                      NaN
#
#    husb_jpn_wife_british  husb_jpn_wife_chinese  husb_jpn_wife_filipino  \
# 0                    NaN                    121                     NaN
# 1                    NaN                    280                     NaN
# 2                    NaN                    325                     NaN
# 3                    NaN                    445                     NaN
# 4                    NaN                    410                     NaN
#
#    husb_jpn_wife_korean  husb_jpn_wife_other  husb_jpn_wife_peruvian  \
# 0                   843                   39                     NaN
# 1                  1536                  217                     NaN
# 2                  1696                  232                     NaN
# 3                  1785                  342                     NaN
# 4                  1902                  415                     NaN
#
#    husb_jpn_wife_thai  wife_jpn_husb_american  wife_jpn_husb_brazilian  \
# 0                 NaN                    1592                      NaN
# 1                 NaN                    1571                      NaN
# 2                 NaN                    1252                      NaN
# 3                 NaN                    1010                      NaN
# 4                 NaN                    1024                      NaN
#
#    wife_jpn_husb_british  wife_jpn_husb_chinese  wife_jpn_husb_filipino  \
# 0                    NaN                    158                     NaN
# 1                    NaN                    195                     NaN
# 2                    NaN                    194                     NaN
# 3                    NaN                    237                     NaN
# 4                    NaN                    238                     NaN
#
#    wife_jpn_husb_korean  wife_jpn_husb_other  wife_jpn_husb_peruvian  \
# 0                  1128                  211                     NaN
# 1                  1386                  286                     NaN
# 2                  1533                  261                     NaN
# 3                  1707                  368                     NaN
# 4                  1674                  408                     NaN
#
#    wife_jpn_husb_thai
# 0                 NaN
# 1                 NaN
# 2                 NaN
# 3                 NaN
# 4                 NaN

# %%
# Keep a working copy
selected_df = df.copy()

print("Shape of selected dataset:", selected_df.shape)
selected_df.head()
# Out:
# Shape of selected dataset: (56, 20)
#    year  both_japanese  husb_jpn_wife_american  husb_jpn_wife_brazilian  \
# 0  1965         950696                      64                      NaN
# 1  1970        1023859                      75                      NaN
# 2  1971        1085639                      97                      NaN
# 3  1972        1093988                     102                      NaN
# 4  1973        1065730                     122                      NaN
#
#    husb_jpn_wife_british  husb_jpn_wife_chinese  husb_jpn_wife_filipino  \
# 0                    NaN                    121                     NaN
# 1                    NaN                    280                     NaN
# 2                    NaN                    325                     NaN
# 3                    NaN                    445                     NaN
# 4                    NaN                    410                     NaN
#
#    husb_jpn_wife_korean  husb_jpn_wife_other  husb_jpn_wife_peruvian  \
# 0                   843                   39                     NaN
# 1                  1536                  217                     NaN
# 2                  1696                  232                     NaN
# 3                  1785                  342                     NaN
# 4                  1902                  415                     NaN
#
#    husb_jpn_wife_thai  wife_jpn_husb_american  wife_jpn_husb_brazilian  \
# 0                 NaN                    1592                      NaN
# 1                 NaN                    1571                      NaN
# 2                 NaN                    1252                      NaN
# 3                 NaN                    1010                      NaN
# 4                 NaN                    1024                      NaN
#
#    wife_jpn_husb_british  wife_jpn_husb_chinese  wife_jpn_husb_filipino  \
# 0                    NaN                    158                     NaN
# 1                    NaN                    195                     NaN
# 2                    NaN                    194                     NaN
# 3                    NaN                    237                     NaN
# 4                    NaN                    238                     NaN
#
#    wife_jpn_husb_korean  wife_jpn_husb_other  wife_jpn_husb_peruvian  \
# 0                  1128                  211                     NaN
# 1                  1386                  286                     NaN
# 2                  1533                  261                     NaN
# 3                  1707                  368                     NaN
# 4                  1674                  408                     NaN
#
#    wife_jpn_husb_thai
# 0                 NaN
# 1                 NaN
# 2                 NaN
# 3                 NaN
# 4                 NaN

# %% [markdown]
# # Data Inspection

# %%
# Basic structure of the dataset
selected_df.info()
# Out:
# <class 'pandas.DataFrame'>
# RangeIndex: 56 entries, 0 to 55
# Data columns (total 20 columns):
#  #   Column                   Non-Null Count  Dtype
# ---  ------                   --------------  -----
#  0   year                     56 non-null     int64
#  1   both_japanese            56 non-null     int64
#  2   husb_jpn_wife_american   56 non-null     int64
#  3   husb_jpn_wife_brazilian  33 non-null     float64
#  4   husb_jpn_wife_british    33 non-null     float64
#  5   husb_jpn_wife_chinese    56 non-null     int64
#  6   husb_jpn_wife_filipino   33 non-null     float64
#  7   husb_jpn_wife_korean     56 non-null     int64
#  8   husb_jpn_wife_other      56 non-null     int64
#  9   husb_jpn_wife_peruvian   33 non-null     float64
#  10  husb_jpn_wife_thai       33 non-null     float64
#  11  wife_jpn_husb_american   56 non-null     int64
#  12  wife_jpn_husb_brazilian  33 non-null     float64
#  13  wife_jpn_husb_british    33 non-null     float64
#  14  wife_jpn_husb_chinese    56 non-null     int64
#  15  wife_jpn_husb_filipino   33 non-null     float64
#  16  wife_jpn_husb_korean     56 non-null     int64
#  17  wife_jpn_husb_other      56 non-null     int64
#  18  wife_jpn_husb_peruvian   33 non-null     float64
#  19  wife_jpn_husb_thai       33 non-null     float64
# dtypes: float64(10), int64(10)
# memory usage: 8.9 KB

# %%
# Statistical summary
selected_df.describe()
# Out:
#               year  both_japanese  husb_jpn_wife_american  \
# count    56.000000   5.600000e+01               56.000000
# mean   1996.428571   7.265299e+05              202.267857
# std      16.440368   1.439229e+05               48.517472
# min    1965.000000   4.562660e+05               64.000000
# 25%    1982.750000   6.638145e+05              178.750000
# 50%    1996.500000   7.192785e+05              206.500000
# 75%    2010.250000   7.668912e+05              237.000000
# max    2024.000000   1.093988e+06              286.000000
#
#        husb_jpn_wife_brazilian  husb_jpn_wife_british  husb_jpn_wife_chinese  \
# count                33.000000              33.000000              56.000000
# mean                334.272727              66.242424            4889.571429
# std                 127.056895              16.161355            4005.963327
# min                 209.000000              38.000000             121.000000
# 25%                 255.000000              53.000000            1614.250000
# 50%                 288.000000              62.000000            4229.000000
# 75%                 347.000000              81.000000            7068.500000
# max                 645.000000              99.000000           13936.000000
#
#        husb_jpn_wife_filipino  husb_jpn_wife_korean  husb_jpn_wife_other  \
# count               33.000000             56.000000            56.000000
# mean              5501.848485           3584.142857          2075.017857
# std               2541.684531           1913.841405          1610.016877
# min               1780.000000            843.000000            39.000000
# 25%               3371.000000           1993.000000           885.750000
# 50%               5771.000000           3153.500000          1966.000000
# 75%               7188.000000           5086.750000          2647.250000
# max              12150.000000           8940.000000          8013.000000
#
#        husb_jpn_wife_peruvian  husb_jpn_wife_thai  wife_jpn_husb_american  \
# count               33.000000           33.000000               56.000000
# mean               114.727273         1334.878788             1128.071429
# std                 25.792771          440.181195              305.279119
# min                 70.000000          637.000000              539.000000
# 25%                 92.000000          976.000000              933.500000
# 50%                116.000000         1338.000000             1139.000000
# 75%                138.000000         1688.000000             1376.500000
# max                166.000000         2137.000000             1592.000000
#
#        wife_jpn_husb_brazilian  wife_jpn_husb_british  wife_jpn_husb_chinese  \
# count                33.000000              33.000000              56.000000
# mean                262.787879             262.727273             638.464286
# std                  57.868254              59.777333             303.589973
# min                 146.000000             168.000000             158.000000
# 25%                 231.000000             222.000000             293.250000
# 50%                 270.000000             240.000000             771.000000
# 75%                 299.000000             316.000000             857.000000
# max                 346.000000             386.000000            1104.000000
#
#        wife_jpn_husb_filipino  wife_jpn_husb_korean  wife_jpn_husb_other  \
# count               33.000000             56.000000            56.000000
# mean               143.636364           2016.892857          1471.785714
# std                 66.633709            468.034135           867.382284
# min                 46.000000           1128.000000           211.000000
# 25%                101.000000           1627.750000           515.000000
# 50%                138.000000           1858.000000          1706.500000
# 75%                188.000000           2482.500000          2248.500000
# max                269.000000           2842.000000          2783.000000
#
#        wife_jpn_husb_peruvian  wife_jpn_husb_thai
# count               33.000000           33.000000
# mean               104.787879           39.969697
# std                 21.871439           16.470589
# min                 56.000000           13.000000
# 25%                 92.000000           29.000000
# 50%                106.000000           36.000000
# 75%                123.000000           54.000000
# max                137.000000           75.000000

# %%
# Missing values summary table
missing_summary = selected_df.isnull().sum().reset_index()
missing_summary.columns = ["column", "missing_count"]
missing_summary[missing_summary["missing_count"] > 0]
# Out:
#                      column  missing_count
# 3   husb_jpn_wife_brazilian             23
# 4     husb_jpn_wife_british             23
# 6    husb_jpn_wife_filipino             23
# 9    husb_jpn_wife_peruvian             23
# 10       husb_jpn_wife_thai             23
# 12  wife_jpn_husb_brazilian             23
# 13    wife_jpn_husb_british             23
# 15   wife_jpn_husb_filipino             23
# 18   wife_jpn_husb_peruvian             23
# 19       wife_jpn_husb_thai             23

# %%
# Check duplicate rows
selected_df.duplicated().sum()
# Display duplicate rows if any
selected_df[selected_df.duplicated()]
# Out:
# Empty DataFrame
# Columns: [year, both_japanese, husb_jpn_wife_american, husb_jpn_wife_brazilian, husb_jpn_wife_british, husb_jpn_wife_chinese, husb_jpn_wife_filipino, husb_jpn_wife_korean, husb_jpn_wife_other, husb_jpn_wife_peruvian, husb_jpn_wife_thai, wife_jpn_husb_american, wife_jpn_husb_brazilian, wife_jpn_husb_british, wife_jpn_husb_chinese, wife_jpn_husb_filipino, wife_jpn_husb_korean, wife_jpn_husb_other, wife_jpn_husb_peruvian, wife_jpn_husb_thai]
# Index: []

# %% [markdown]
# # Data Cleaning

# %%
clean_df = selected_df.copy()
# Sort by year
clean_df = clean_df.sort_values("year").reset_index(drop=True)

# Remove duplicate rows
clean_df = clean_df.drop_duplicates()

print("Shape after cleaning duplicates:", clean_df.shape)
clean_df.head()
# Out:
# Shape after cleaning duplicates: (56, 20)
#    year  both_japanese  husb_jpn_wife_american  husb_jpn_wife_brazilian  \
# 0  1965         950696                      64                      NaN
# 1  1970        1023859                      75                      NaN
# 2  1971        1085639                      97                      NaN
# 3  1972        1093988                     102                      NaN
# 4  1973        1065730                     122                      NaN
#
#    husb_jpn_wife_british  husb_jpn_wife_chinese  husb_jpn_wife_filipino  \
# 0                    NaN                    121                     NaN
# 1                    NaN                    280                     NaN
# 2                    NaN                    325                     NaN
# 3                    NaN                    445                     NaN
# 4                    NaN                    410                     NaN
#
#    husb_jpn_wife_korean  husb_jpn_wife_other  husb_jpn_wife_peruvian  \
# 0                   843                   39                     NaN
# 1                  1536                  217                     NaN
# 2                  1696                  232                     NaN
# 3                  1785                  342                     NaN
# 4                  1902                  415                     NaN
#
#    husb_jpn_wife_thai  wife_jpn_husb_american  wife_jpn_husb_brazilian  \
# 0                 NaN                    1592                      NaN
# 1                 NaN                    1571                      NaN
# 2                 NaN                    1252                      NaN
# 3                 NaN                    1010                      NaN
# 4                 NaN                    1024                      NaN
#
#    wife_jpn_husb_british  wife_jpn_husb_chinese  wife_jpn_husb_filipino  \
# 0                    NaN                    158                     NaN
# 1                    NaN                    195                     NaN
# 2                    NaN                    194                     NaN
# 3                    NaN                    237                     NaN
# 4                    NaN                    238                     NaN
#
#    wife_jpn_husb_korean  wife_jpn_husb_other  wife_jpn_husb_peruvian  \
# 0                  1128                  211                     NaN
# 1                  1386                  286                     NaN
# 2                  1533                  261                     NaN
# 3                  1707                  368                     NaN
# 4                  1674                  408                     NaN
#
#    wife_jpn_husb_thai
# 0                 NaN
# 1                 NaN
# 2                 NaN
# 3                 NaN
# 4                 NaN

# %%
# Convert all columns except year to numeric
for col in clean_df.columns:
    if col != "year":
        clean_df[col] = pd.to_numeric(clean_df[col], errors="coerce")

clean_df.info()
# Out:
# <class 'pandas.DataFrame'>
# RangeIndex: 56 entries, 0 to 55
# Data columns (total 20 columns):
#  #   Column                   Non-Null Count  Dtype
# ---  ------                   --------------  -----
#  0   year                     56 non-null     int64
#  1   both_japanese            56 non-null     int64
#  2   husb_jpn_wife_american   56 non-null     int64
#  3   husb_jpn_wife_brazilian  33 non-null     float64
#  4   husb_jpn_wife_british    33 non-null     float64
#  5   husb_jpn_wife_chinese    56 non-null     int64
#  6   husb_jpn_wife_filipino   33 non-null     float64
#  7   husb_jpn_wife_korean     56 non-null     int64
#  8   husb_jpn_wife_other      56 non-null     int64
#  9   husb_jpn_wife_peruvian   33 non-null     float64
#  10  husb_jpn_wife_thai       33 non-null     float64
#  11  wife_jpn_husb_american   56 non-null     int64
#  12  wife_jpn_husb_brazilian  33 non-null     float64
#  13  wife_jpn_husb_british    33 non-null     float64
#  14  wife_jpn_husb_chinese    56 non-null     int64
#  15  wife_jpn_husb_filipino   33 non-null     float64
#  16  wife_jpn_husb_korean     56 non-null     int64
#  17  wife_jpn_husb_other      56 non-null     int64
#  18  wife_jpn_husb_peruvian   33 non-null     float64
#  19  wife_jpn_husb_thai       33 non-null     float64
# dtypes: float64(10), int64(10)
# memory usage: 8.9 KB

# %%
# Columns where husband is Japanese and wife is foreign
husb_foreign_cols = [col for col in clean_df.columns if col.startswith("husb_jpn_wife_")]

# Columns where wife is Japanese and husband is foreign
wife_foreign_cols = [col for col in clean_df.columns if col.startswith("wife_jpn_husb_")]

print("Husband Japanese + foreign wife columns:")
print(husb_foreign_cols)

print("\nWife Japanese + foreign husband columns:")
print(wife_foreign_cols)
# Out:
# Husband Japanese + foreign wife columns:
# ['husb_jpn_wife_american', 'husb_jpn_wife_brazilian', 'husb_jpn_wife_british', 'husb_jpn_wife_chinese', 'husb_jpn_wife_filipino', 'husb_jpn_wife_korean', 'husb_jpn_wife_other', 'husb_jpn_wife_peruvian', 'husb_jpn_wife_thai']
#
# Wife Japanese + foreign husband columns:
# ['wife_jpn_husb_american', 'wife_jpn_husb_brazilian', 'wife_jpn_husb_british', 'wife_jpn_husb_chinese', 'wife_jpn_husb_filipino', 'wife_jpn_husb_korean', 'wife_jpn_husb_other', 'wife_jpn_husb_peruvian', 'wife_jpn_husb_thai']

# %%
# Combine all foreign-country categories
clean_df["total_husb_jpn_foreign_wife"] = clean_df[husb_foreign_cols].sum(axis=1, skipna=True)
clean_df["total_wife_jpn_foreign_husband"] = clean_df[wife_foreign_cols].sum(axis=1, skipna=True)

# Drop 1965 to keep a continuous yearly sequence from 1970 onward
clean_df = clean_df[clean_df["year"] != 1965].reset_index(drop=True)

# Total marriages involving a foreign spouse
clean_df["total_foreign_spouse"] = (
    clean_df["total_husb_jpn_foreign_wife"] +
    clean_df["total_wife_jpn_foreign_husband"]
)

# Total marriages
clean_df["total_marriages"] = (
    clean_df["both_japanese"] +
    clean_df["total_foreign_spouse"]
)
clean_df.head()
# Out:
#    year  both_japanese  husb_jpn_wife_american  husb_jpn_wife_brazilian  \
# 0  1970        1023859                      75                      NaN
# 1  1971        1085639                      97                      NaN
# 2  1972        1093988                     102                      NaN
# 3  1973        1065730                     122                      NaN
# 4  1974         994096                     142                      NaN
#
#    husb_jpn_wife_british  husb_jpn_wife_chinese  husb_jpn_wife_filipino  \
# 0                    NaN                    280                     NaN
# 1                    NaN                    325                     NaN
# 2                    NaN                    445                     NaN
# 3                    NaN                    410                     NaN
# 4                    NaN                    477                     NaN
#
#    husb_jpn_wife_korean  husb_jpn_wife_other  husb_jpn_wife_peruvian  ...  \
# 0                  1536                  217                     NaN  ...
# 1                  1696                  232                     NaN  ...
# 2                  1785                  342                     NaN  ...
# 3                  1902                  415                     NaN  ...
# 4                  2047                  511                     NaN  ...
#
#    wife_jpn_husb_chinese  wife_jpn_husb_filipino  wife_jpn_husb_korean  \
# 0                    195                     NaN                  1386
# 1                    194                     NaN                  1533
# 2                    237                     NaN                  1707
# 3                    238                     NaN                  1674
# 4                    229                     NaN                  1743
#
#    wife_jpn_husb_other  wife_jpn_husb_peruvian  wife_jpn_husb_thai  \
# 0                  286                     NaN                 NaN
# 1                  261                     NaN                 NaN
# 2                  368                     NaN                 NaN
# 3                  408                     NaN                 NaN
# 4                  420                     NaN                 NaN
#
#    total_husb_jpn_foreign_wife  total_wife_jpn_foreign_husband  \
# 0                       2108.0                          3438.0
# 1                       2350.0                          3240.0
# 2                       2674.0                          3322.0
# 3                       2849.0                          3344.0
# 4                       3177.0                          3182.0
#
#    total_foreign_spouse  total_marriages
# 0                5546.0        1029405.0
# 1                5590.0        1091229.0
# 2                5996.0        1099984.0
# 3                6193.0        1071923.0
# 4                6359.0        1000455.0
#
# [5 rows x 24 columns]

# %% [markdown]
# # Data Preparation

# %%
jap_copy_df = clean_df[
    [
        "year",
        "both_japanese",
        "total_husb_jpn_foreign_wife",
        "total_wife_jpn_foreign_husband",
        "total_foreign_spouse",
        "total_marriages"
    ]
].copy()

jap_copy_df.head()
# Out:
#    year  both_japanese  total_husb_jpn_foreign_wife  \
# 0  1970        1023859                       2108.0
# 1  1971        1085639                       2350.0
# 2  1972        1093988                       2674.0
# 3  1973        1065730                       2849.0
# 4  1974         994096                       3177.0
#
#    total_wife_jpn_foreign_husband  total_foreign_spouse  total_marriages
# 0                          3438.0                5546.0        1029405.0
# 1                          3240.0                5590.0        1091229.0
# 2                          3322.0                5996.0        1099984.0
# 3                          3344.0                6193.0        1071923.0
# 4                          3182.0                6359.0        1000455.0

# %%
jap_df = jap_copy_df.melt(
    id_vars="year",
    var_name="type",
    value_name="amount"
)

jap_df.head()
# Out:
#    year           type     amount
# 0  1970  both_japanese  1023859.0
# 1  1971  both_japanese  1085639.0
# 2  1972  both_japanese  1093988.0
# 3  1973  both_japanese  1065730.0
# 4  1974  both_japanese   994096.0

# %%
jap_df.info()
# Out:
# <class 'pandas.DataFrame'>
# RangeIndex: 275 entries, 0 to 274
# Data columns (total 3 columns):
#  #   Column  Non-Null Count  Dtype
# ---  ------  --------------  -----
#  0   year    275 non-null    int64
#  1   type    275 non-null    str
#  2   amount  275 non-null    float64
# dtypes: float64(1), int64(1), str(1)
# memory usage: 6.6 KB

# %%
jap_df.isnull().sum()
# Out:
# year      0
# type      0
# amount    0
# dtype: int64

# %%
jap_df["type"].value_counts()
# Out:
# type
# both_japanese                     55
# total_husb_jpn_foreign_wife       55
# total_wife_jpn_foreign_husband    55
# total_foreign_spouse              55
# total_marriages                   55
# Name: count, dtype: int64

# %%
jap_df = jap_df.sort_values("year").reset_index(drop=True)
jap_df
# Out:
#      year                            type     amount
# 0    1970                   both_japanese  1023859.0
# 1    1970            total_foreign_spouse     5546.0
# 2    1970  total_wife_jpn_foreign_husband     3438.0
# 3    1970                 total_marriages  1029405.0
# 4    1970     total_husb_jpn_foreign_wife     2108.0
# ..    ...                             ...        ...
# 270  2024  total_wife_jpn_foreign_husband     6903.0
# 271  2024     total_husb_jpn_foreign_wife    11517.0
# 272  2024            total_foreign_spouse    18420.0
# 273  2024                   both_japanese   466672.0
# 274  2024                 total_marriages   485092.0
#
# [275 rows x 3 columns]

# %% [markdown]
# # Model Training

# %%
from sklearn.linear_model import LinearRegression
from sklearn.preprocessing import PolynomialFeatures
from sklearn.pipeline import Pipeline
from sklearn.metrics import r2_score, mean_absolute_error

# %%
# Make sure required columns are valid
jap_df["year"] = pd.to_numeric(jap_df["year"], errors="coerce")
jap_df["amount"] = pd.to_numeric(jap_df["amount"], errors="coerce")

# Drop rows with missing values in required columns
jap_df = jap_df.dropna(subset=["year", "type", "amount"]).copy()

# Sort data
jap_df = jap_df.sort_values(["type", "year"]).reset_index(drop=True)

jap_df.head()
# Out:
#    year           type     amount
# 0  1970  both_japanese  1023859.0
# 1  1971  both_japanese  1085639.0
# 2  1972  both_japanese  1093988.0
# 3  1973  both_japanese  1065730.0
# 4  1974  both_japanese   994096.0

# %%
train_cutoff = 2019
future_year = 2025
degree = 2

poly_results = []
poly_predictions = []

categories = jap_df["type"].unique()

for category in categories:
    subset = jap_df[jap_df["type"] == category].copy()
    
    train_df = subset[subset["year"] <= train_cutoff].copy()
    test_df = subset[subset["year"] > train_cutoff].copy()
    
    if train_df.empty or test_df.empty:
        print(f"Skipping {category}: not enough train/test data.")
        continue
    
    X_train = train_df[["year"]]
    y_train = train_df["amount"]
    
    X_test = test_df[["year"]]
    y_test = test_df["amount"]
    
    # Polynomial Regression model
    model = Pipeline([
        ("poly", PolynomialFeatures(degree=degree, include_bias=False)),
        ("linear", LinearRegression())
    ])
    
    model.fit(X_train, y_train)
    
    # Predictions
    y_train_pred = model.predict(X_train)
    y_test_pred = model.predict(X_test)
    pred_2025 = model.predict(pd.DataFrame({"year": [future_year]}))[0]
    
    # Metrics
    train_r2 = r2_score(y_train, y_train_pred)
    test_r2 = r2_score(y_test, y_test_pred)
    
    train_mae = mean_absolute_error(y_train, y_train_pred)
    test_mae = mean_absolute_error(y_test, y_test_pred)
    
    # Save summary
    poly_results.append({
        "type": category,
        "degree": degree,
        "train_start_year": int(train_df["year"].min()),
        "train_end_year": int(train_df["year"].max()),
        "test_start_year": int(test_df["year"].min()),
        "test_end_year": int(test_df["year"].max()),
        "train_r2": train_r2,
        "test_r2": test_r2,
        "train_mae": train_mae,
        "test_mae": test_mae,
        "prediction_2025": pred_2025
    })
    
    # Save detailed predictions
    train_temp = train_df.copy()
    train_temp["set"] = "train"
    train_temp["predicted_amount"] = y_train_pred
    
    test_temp = test_df.copy()
    test_temp["set"] = "test"
    test_temp["predicted_amount"] = y_test_pred
    
    combined_temp = pd.concat([train_temp, test_temp], ignore_index=True)
    poly_predictions.append(combined_temp)

# %%
results_df = pd.DataFrame(poly_results)
results_df
# Out:
#                              type  degree  train_start_year  train_end_year  \
# 0                   both_japanese       2              1970            2019
# 1            total_foreign_spouse       2              1970            2019
# 2     total_husb_jpn_foreign_wife       2              1970            2019
# 3                 total_marriages       2              1970            2019
# 4  total_wife_jpn_foreign_husband       2              1970            2019
#
#    test_start_year  test_end_year  train_r2    test_r2     train_mae  \
# 0             2020           2024  0.748400 -80.088973  54083.475920
# 1             2020           2024  0.752479 -14.151156   4796.534322
# 2             2020           2024  0.740021 -18.351861   4125.981856
# 3             2020           2024  0.682552 -94.044022  58475.653870
# 4             2020           2024  0.790145  -1.375970    797.931456
#
#         test_mae  prediction_2025
# 0  165316.301764    654572.410274
# 1    3696.177880     17555.015007
# 2    3628.066612     11139.199662
# 3  169012.479644    672127.425281
# 4     260.949236      6415.815345

# %%
predictions_df = pd.concat(poly_predictions, ignore_index=True)
predictions_df.head()
# Out:
#    year           type     amount    set  predicted_amount
# 0  1970  both_japanese  1023859.0  train     987349.606425
# 1  1971  both_japanese  1085639.0  train     972030.891401
# 2  1972  both_japanese  1093988.0  train     957055.443804
# 3  1973  both_japanese  1065730.0  train     942423.263635
# 4  1974  both_japanese   994096.0  train     928134.350894

# %% [markdown]
# # Model Visualization

# %%
import matplotlib.pyplot as plt


label_map = {
    "both_japanese": "Both Japanese",
    "total_husb_jpn_foreign_wife": "Japanese Husband + Foreign Wife",
    "total_wife_jpn_foreign_husband": "Japanese Wife + Foreign Husband",
    "total_foreign_spouse": "Total Foreign Spouse",
    "total_marriages": "Total Marriages"
}
for category in results_df["type"]:
    subset = predictions_df[predictions_df["type"] == category].copy()
    
    train_subset = subset[subset["set"] == "train"]
    test_subset = subset[subset["set"] == "test"]
    
    plt.figure(figsize=(10, 5))
    
    plt.scatter(train_subset["year"], train_subset["amount"], label="Train Actual")
    plt.scatter(test_subset["year"], test_subset["amount"], label="Test Actual")
    
    # Sort by year for smooth plotting
    subset = subset.sort_values("year")
    plt.plot(subset["year"], subset["predicted_amount"], label=f"Polynomial Regression (degree={degree})")
    
    plt.axvline(x=train_cutoff, linestyle="--", label="Train/Test Split")

    nice_name = label_map.get(category, category)
    
    plt.title(f"{nice_name}: Polynomial Regression")
    plt.xlabel("Year")
    plt.ylabel("Amount")
    plt.legend()
    plt.grid(True)
    plt.show()

# %% [markdown]
# # 2025 Predictions

# %%
prediction_2025_df = results_df[["type", "prediction_2025"]].copy()
prediction_2025_df
# Out:
#                              type  prediction_2025
# 0                   both_japanese    654572.410274
# 1            total_foreign_spouse     17555.015007
# 2     total_husb_jpn_foreign_wife     11139.199662
# 3                 total_marriages    672127.425281
# 4  total_wife_jpn_foreign_husband      6415.815345

# %%
degree = 2

for category in results_df["type"]:
    actual_subset = jap_df[jap_df["type"] == category].copy()
    fitted_subset = predictions_df[predictions_df["type"] == category].copy()
    pred_2025_subset = prediction_2025_df[prediction_2025_df["type"] == category].copy()
    
    # Sort for clean plotting
    actual_subset = actual_subset.sort_values("year")
    fitted_subset = fitted_subset.sort_values("year")
    
    pred_year = 2025
    pred_amount = pred_2025_subset["prediction_2025"].values[0]
    
    plt.figure(figsize=(10, 5))
    
    # Historical actual data
    plt.scatter(actual_subset["year"], actual_subset["amount"], label="Historical Data")
    
    # Polynomial regression fitted line
    plt.plot(fitted_subset["year"], fitted_subset["predicted_amount"], label="Polynomial Regression Line")
    
    # Predicted 2025 point
    plt.scatter(pred_year, pred_amount, s=120, label="Predicted 2025")
    
    # Connect the curve to 2025
    last_year = fitted_subset["year"].max()
    last_pred = fitted_subset.loc[fitted_subset["year"].idxmax(), "predicted_amount"]
    plt.plot([last_year, pred_year], [last_pred, pred_amount], linestyle="--")
    
    plt.title(f"{nice_name}: Polynomial Regression with 2025 Prediction")
    plt.xlabel("Year")
    plt.ylabel("Amount")
    plt.legend()
    plt.grid(True)
    plt.show()
